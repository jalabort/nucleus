# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline

# %%
from nucleus.dataset.datasets.jersey import BasketballJerseyDataset


ds = BasketballJerseyDataset()
# Out:
# ...
# Fragments already downloaded

# %%
ds.df
# Out:
#                 labels                                               path
# 0        [visible, 23]  s3://hudlrd-experiments/jersey-tagging/images/...
# 1        [visible, 04]  s3://hudlrd-experiments/jersey-tagging/images/...
# 2     [occluded, None]  s3://hudlrd-experiments/jersey-tagging/images/...
# 3        [visible, 41]  s3://hudlrd-experiments/jersey-tagging/images/...
# 4     [occluded, None]  s3://hudlrd-experiments/jersey-tagging/images/...
# 5     [occluded, None]  s3://hudlrd-experiments/jersey-tagging/images/...
# 6        [visible, 05]  s3://hudlrd-experiments/jersey-tagging/images/...
# 7        [visible, 05]  s3://hudlrd-experiments/jersey-tagging/images/...
# 8        [visible, 53]  s3://hudlrd-experiments/jersey-tagging/images/...
# 9        [visible, 03]  s3://hudlrd-experiments/jersey-tagging/images/...
# 10    [occluded, None]  s3://hudlrd-experiments/jersey-tagging/images/...
# 11       [visible, 05]  s3://hudlrd-experiments/jersey-tagging/images/...
# ...

# %%
ds.unique_labels()
# Out:
# [['occluded', 'visible'],
#  ['00',
#   '01',
#   '02',
#   '03',
#   '04',
#   '05',
#   '09',
#   '10',
#   '11',
#   '12',
#   '13',
#   '14',
#   '15',
#   '20',
#   '21',
#   '22',
#   '23',
#   '24',
#   '25',
#   '26',
#   '27',
#   '30',
#   '31',
#   '32',
#   '33',
#   '34',
#   '35',
#   '37',
#   '40',
#   '41',
#   '42',
#   '43',
#   '44',
#   '45',
#   '50',
#   '52',
#   '53',
#   '54',
#   '55']]

# %%
dfs = ds.create_label_count_df()

# %%
dfs[0]
# Out:
#       label  count
# 0  occluded    736
# 1   visible   1206

# %%
dfs[1]
# Out:
#    label  count
# 0     00     18
# 1     01     44
# 2     02     76
# 3     03    114
# 4     04     72
# 5     05     80
# 6     09      1
# 7     10     59
# 8     11     52
# 9     12     63
# 10    13     29
# 11    14     39
# 12    15     56
# 13    20     42
# 14    21     47
# 15    22     74
# 16    23     74
# 17    24     44
# 18    25     27
# 19    26      1
# 20    27      1
# 21    30     29
# 22    31     14
# 23    32     28
# 24    33     35
# 25    34     25
# 26    35     14
# 27    37      1
# 28    40      7
# 29    41      3
# 30    42      5
# 31    43      2
# 32    44     16
# 33    45      2
# 34    50      3
# 35    52      4
# 36    53      3
# 37    54      1
# 38    55      1

# %%
ds.view_labels_distributions(vertical=True)

# %%
ds.view_row(0)

# %%
# %time ds.save()
# Out:
# ...
# CPU times: user 32.9 s, sys: 3.63 s, total: 36.6 s
# Wall time: 19.7 s

# %%
# %time ds.save()
# Out:
# ...
# CPU times: user 650 ms, sys: 80 ms, total: 730 ms
# Wall time: 670 ms

# %%
ds.df
# Out:
#                 labels                                               path
# 0        [visible, 23]  /Users/joan.alabort/cvdev/specialist/week1/nuc...
# 1        [visible, 04]  /Users/joan.alabort/cvdev/specialist/week1/nuc...
# 2     [occluded, None]  /Users/joan.alabort/cvdev/specialist/week1/nuc...
# 3        [visible, 41]  /Users/joan.alabort/cvdev/specialist/week1/nuc...
# 4     [occluded, None]  /Users/joan.alabort/cvdev/specialist/week1/nuc...
# 5     [occluded, None]  /Users/joan.alabort/cvdev/specialist/week1/nuc...
# 6        [visible, 05]  /Users/joan.alabort/cvdev/specialist/week1/nuc...
# 7        [visible, 05]  /Users/joan.alabort/cvdev/specialist/week1/nuc...
# 8        [visible, 53]  /Users/joan.alabort/cvdev/specialist/week1/nuc...
# 9        [visible, 03]  /Users/joan.alabort/cvdev/specialist/week1/nuc...
# 10    [occluded, None]  /Users/joan.alabort/cvdev/specialist/week1/nuc...
# 11       [visible, 05]  /Users/joan.alabort/cvdev/specialist/week1/nuc...
# ...
